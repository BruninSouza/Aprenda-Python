# %% [markdown]
# # **8. Módulos e Pacotes**

# %% [markdown]
# À medida que os seus projetos em Python crescem, manter todo o código em um único arquivo torna-se inviável. É aqui que entram os conceitos de Módulos e Pacotes, permitindo a organização, manutenção e reutilização do código.

# %% [markdown]
# ## **O que são Módulos e Pacotes?**

# %% [markdown]
# * **Módulos**: É qualquer arquivo com a extensão `.py`. Ele funciona como uma caixa de ferramentas que contém funções, variáveis e classes específicas (ex: `calculos.py`).
#
# * **Pacotes**: É uma pasta que contém um ou mais módulos. Em projetos Python, pastas de pacotes costumam conter um arquivo especial chamado `__init__.py`, que indica ao interpretador que aquela pasta é, de fato, um pacote importável.

# %% [markdown]
# ## **Importando Ferramentas**

# %% [markdown]
# O Python possui "pilhas incluídas" (a *Standard Library*), o que significa que muitos módulos já vêm instalados. Para usá-los, empregamos a instrução `import` seguida pelo nome do módulo desejado.
#
# Existem três formas principais de importar:

# %% [markdown]
# 1. **Importação Direta**: Traz o módulo inteiro.

# %%
import math # importando módulo math
print(math.sqrt(25)) # Saída: 5.0
# Out:
# 5.0

# %% [markdown]
# 2. **Importação Seletiva**: Traz apenas uma ferramenta específica do módulo.

# %%
from math import pi # Importando função pi do módulo math
print(pi) # Saída: 3.141592653589793
# Out:
# 3.141592653589793

# %% [markdown]
# 3. **Importação com Apelido** (Alias): Muito comum em Ciência de Dados para economizar digitação.

# %%
import math as mt # Importando e apelidando o módulo math como mt
print(mt.sqrt(144)) # Saída: 12.0
# Out:
# 12.0

# %% [markdown]
# ### **Instalando Bibliotecas Externas**

# %% [markdown]
# Nem tudo vem instalado no **Python** por padrão. Para acessar o vasto ecossistema da **comunidade global** (PyPI), utilizamos o gerenciador de pacotes *PIP*.
#
# Para instalar uma biblioteca global usamos o comando `pip install` seguido pelo nome do pacote que desejamos.

# %% [markdown]
# > 🔴 **Importante**: Em ambientes interativos como o Google Colab ou Jupyter Notebook, você pode instalar pacotes diretamente em uma célula de código colocando um ponto de exclamação ! antes do comando:

# %%
# Executa a instalação no terminal virtual do Colab
# !pip install yfinance (retire a # do inicio para testar)

# Após a instalação, basta importar e usar
# import yfinance as yf (retire a # do inicio para testar)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Executa a instalação no terminal virtual do Colab
# ----> 2 get_ipython().system('pip install yfinance')
#       4 # Após a instalação, basta importar e usar
#       5 import yfinance as yf
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1481, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1523, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1324, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1961, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File ~/Área de trabalho/Pasta/projetos/projetos-pessoais/Estudo-Python/venv/lib/python3.12/site-packages/debugpy/_vendored/pydevd/pydevd.py:2199, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2196             from_this_thread.append(frame_custom_thread_id)
#    2198     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2199         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2201 frames_list = None
#    2203 if keep_suspended:
#    2204     # This means that we should pause again after a set next statement.
#
# File ~/Área de trabalho/Pasta/projetos/projetos-pessoais/Estudo-Python/venv/lib/python3.12/site-packages/debugpy/_vendored/pydevd/pydevd.py:2268, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2265                 queue.put(internal_cmd)
#    2266                 wait_timeout = TIMEOUT_FAST
# -> 2268         notify_event.wait(wait_timeout)
#    2269         notify_event.clear()
#    2271 finally:
#
# File /usr/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /usr/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# > 🎉 **Excelente trabalho!** Você aprendeu a estruturar seu projeto em múltiplos arquivos e a importar bibliotecas externas. Essa organização é o padrão de mercado para manter a clareza e escalar projetos maiores.
